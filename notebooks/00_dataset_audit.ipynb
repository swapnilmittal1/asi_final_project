# %% [markdown]
# # 00 — Dataset audit (CoAID + SNAP ego-Twitter)
#
# Authoritative write-up: `docs/dataset_audit.md`. This notebook is for quick re-checks.

# %%
from pathlib import Path
import sys

ROOT = Path("..").resolve()
sys.path.insert(0, str(ROOT / "src"))
from config import COAID_RAW, TWITTER_RAW, PROJECT_ROOT

print("PROJECT_ROOT", PROJECT_ROOT)
print("CoAID path", COAID_RAW, "exists", COAID_RAW.exists())
print("Twitter path", TWITTER_RAW, "exists", TWITTER_RAW.exists())
print("ego .edges count", len(list(TWITTER_RAW.glob("*.edges"))))
print("empty .circles", sum(1 for p in TWITTER_RAW.glob("*.circles") if p.stat().st_size == 0))
